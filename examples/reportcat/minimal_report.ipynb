# %% [markdown]
# # Minimal report example
#
# This notebook demonstrates a simple parameterized report using reportcat.

# %%
# parameters
x = 1
y = 2

# %%
result = x + y
print(f"x = {x}")
print(f"y = {y}")
print(f"result = {result}")

# %% [markdown]
# The output above confirms that papermill parameters were injected successfully and the notebook was converted into an HTML report using reportcat.
