# %% [markdown]
# # Minimal report example
#
# This notebook demonstrates a simple parameterized report using reportcat.

# %%
# parameters
x = 1
y = 2

# %% [markdown]
# ## Example calculation
#
# This cell uses the injected parameters to produce a simple output.

# %%
result = x + y

print("Injected parameter values:")
print("-------------------------")
print(f"x = {x}")
print(f"y = {y}")
print(f"result = {result}")

# %% [markdown]
# This output confirms that papermill parameters were injected successfully and the notebook was rendered as an HTML report using reportcat.
